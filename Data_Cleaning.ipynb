# %%
import pandas as pd
import geopandas as gpd
import numpy as np

# %% [markdown]
# # Indep variable cleaning

# %%
multifamily = {'R-M', 'R-M(PD)', 'R-M(CL)', 'R-2', 'R-2(PD)', 'UV', 'CP', 
               'CP(PD)', 'MUC', 'MUN', 'DC', 'DC-NT1', 'DC(PD)'}
#confirm what R-M(CL) means
#make sure we don't need to include others

# %%
sj_zips = gpd.read_file('Zip_Code_Boundary.geojson')
sj_zips = sj_zips.to_crs(epsg = '3857') #converting crs to planar

# %%
sj_zones = gpd.read_file('zoning_data/Zoning_2022.geojson')
sj_zones = sj_zones.to_crs(epsg = '3857') #converting crs to planar

# %%
sj_zones['area'] = sj_zones.area #creating area column

# %%
#check number of parcels between years
# calculate size from geometry
# check change in other zoning proportions
# urban institute yonah freemark

# capture pressure on housing
# -> 
# base rent and total housing units in log
# include base proportion of multifamily

# %%
#only one row where the zoningabbrev != zoning
sj_zones[sj_zones['ZONING'] != sj_zones['ZONINGABBREV']]
# Out:
#        OBJECTID FACILITYID   ZONING ZONINGABBREV REZONINGFILE PDUSE PDDENSITY  \
# 12484     27387      13466  R-M(CL)          R-M          NaN   NaN         0
#
#       DEVELOPEDASPD APPROVALDATE COLORCODE                LASTUPDATE NOTES  \
# 12484           NaN          NaN         3 2022-10-11 21:49:45+00:00   NaN
#
#        SHAPE_Length    SHAPE_Area  INTID  \
# 12484   1021.196388  41163.034866  13466
#
#                                                 geometry         area
# 12484  POLYGON ((-13566174.363 4484780.976, -13566204...  6059.180697

# %%
sj_zones['ZONING'].unique()
# Out:
# array(['A', 'R-1-5', 'IP', 'R-2(PD)', 'R-1-8', 'PQP', 'OS', 'R-M',
#        'A(PD)', 'CN', 'R-1-1', 'LI(PD)', 'CP', 'TR', 'R-M(PD)', 'MUC',
#        'CN(PD)', 'TEC', 'CIC', 'UR', 'UV', 'CG', 'UVC', 'DC', 'R-2',
#        'CP(PD)', 'CG(PD)', 'MUN', 'CIC(PD)', 'CO', 'CO(PD)', 'LI',
#        'DC-NT1', 'HI', 'HI(PD)', 'IP(PD)', 'OS(PD)', 'R-1-1(PD)', 'R-1-2',
#        'R-1-2(PD)', 'R-1-5(CL)', 'R-1-5(PD)', 'R-1-8(CL)', 'R-1-8(PD)',
#        'R-1-RR', 'R-M(CL)', 'R-MH', 'WATER', 'PQP(PD)', 'DC(PD)',
#        'TEC(PD)', 'MS-C', 'MS-G'], dtype=object)

# %%
#should this be an inner join or left/right
joined_data = gpd.sjoin(sj_zips, sj_zones, how='inner', predicate='intersects')

# %%
#joined_data[['ZIPCODE', 'FACILITYID', 'ZONING', 'ZONINGABBREV']]

# %%
def calculate_percentage(group):
    total_area = group['area'].sum()
    rm_area = group[group['ZONINGABBREV'].isin(multifamily)]['area'].sum()
    percentage = rm_area / total_area
    return percentage

# %%
percentages = (
    joined_data.groupby('ZIPCODE').apply(calculate_percentage)
    .reset_index(name='multifam_percentage')
)

# %%
joined_data = joined_data.merge(percentages, on = 'ZIPCODE', how = 'left')

# %%
#facilityID/objectID might be the unique ID
joined_data.head()
# Out:
#    OBJECTID_left ZIPCODE           LASTUPDATE_left  SHAPE_Length_left  \
# 0           2448   95113 2021-08-05 16:20:58+00:00       44802.535193
# 1           5267   95110 2021-08-05 16:25:43+00:00      125080.893238
# 2           2448   95113 2021-08-05 16:20:58+00:00       44802.535193
# 3           5267   95110 2021-08-05 16:25:43+00:00      125080.893238
# 4           2448   95113 2021-08-05 16:20:58+00:00       44802.535193
#
#    SHAPE_Area_left SANJOSELIMITS  \
# 0     1.214197e+07           Yes
# 1     1.272895e+08           Yes
# 2     1.214197e+07           Yes
# 3     1.272895e+08           Yes
# 4     1.214197e+07           Yes
#
#                                             geometry  index_right  \
# 0  MULTIPOLYGON (((-13567772.444 4486736.782, -13...        11662
# 1  MULTIPOLYGON (((-13568165.458 4485007.913, -13...        11662
# 2  MULTIPOLYGON (((-13567772.444 4486736.782, -13...        11673
# 3  MULTIPOLYGON (((-13568165.458 4485007.913, -13...        11673
# 4  MULTIPOLYGON (((-13567772.444 4486736.782, -13...         7333
#
#    OBJECTID_right FACILITYID  ... DEVELOPEDASPD APPROVALDATE COLORCODE  \
# 0           11843      11843  ...           NaN          NaN         3
# 1           11843      11843  ...           NaN          NaN         3
# 2           11854      11854  ...           NaN          NaN         3
# 3           11854      11854  ...           NaN          NaN         3
# 4            7463       7463  ...           NaN          NaN         8
#
#            LASTUPDATE_right NOTES SHAPE_Length_right SHAPE_Area_right  INTID  \
# 0 2022-04-22 21:50:37+00:00   NaN        1416.945085    108790.575196  11843
# 1 2022-04-22 21:50:37+00:00   NaN        1416.945085    108790.575196  11843
# 2 2022-04-22 21:50:43+00:00   NaN        1367.437248     76529.248044  11854
# 3 2022-04-22 21:50:43+00:00   NaN        1367.437248     76529.248044  11854
# 4 2023-03-13 23:58:45+00:00   NaN         787.447414     32513.751320   7463
#
#            area multifam_percentage
# 0  16012.548031            0.655577
# 1  16012.548031            0.165249
# 2  11264.828469            0.655577
# 3  11264.828469            0.165249
# 4   4785.660465            0.655577
#
# [5 rows x 25 columns]

# %%
#keep all rows from the left and duplicate them if necessary to represent multiple hits between the two dataframes.
#print(sj_zones.shape[0])
#joined_data.shape[0]

# %%
#i think facilityID/objectID is the zoning district, confirm this
abbrev_data = joined_data[['ZIPCODE', 'FACILITYID', 'ZONINGABBREV', 'multifam_percentage']]

# %%
abbrev_data['ZIPCODE'] = abbrev_data['ZIPCODE'].astype('int64')
# Out:
# /var/folders/dl/8n__h2151hd3n3gtfckwb75w0000gn/T/ipykernel_5565/1191412562.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   abbrev_data['ZIPCODE'] = abbrev_data['ZIPCODE'].astype('int64')

# %%
base_zones = gpd.read_file('zoning_data/Zoning_2012.geojson')

# %%
#is this the right crs?
base_zones['geometry'] = base_zones['geometry'].to_crs(crs = 4326)

# %%
base_joined = gpd.sjoin(sj_zips, base_zones, how='inner', predicate='intersects')

base_percentages = (
    base_joined.groupby('ZIPCODE').apply(calculate_percentage)
    .reset_index(name='multifam_percentage_2012')
)

base_joined = base_joined.merge(base_percentages, on = 'ZIPCODE', how = 'left')

abbrev_base = base_joined[['ZIPCODE', 'FACILITYID', 'ZONINGABBREV', 'multifam_percentage_2012']]
abbrev_base['ZIPCODE'] = abbrev_base['ZIPCODE'].astype('int64')
# Out:
# /var/folders/dl/8n__h2151hd3n3gtfckwb75w0000gn/T/ipykernel_5565/2301465851.py:1: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: EPSG:3857
# Right CRS: EPSG:4326
#
#   base_joined = gpd.sjoin(sj_zips, base_zones, how='inner', predicate='intersects')
# /var/folders/dl/8n__h2151hd3n3gtfckwb75w0000gn/T/ipykernel_5565/2301465851.py:4: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   base_joined.groupby('ZIPCODE').apply(calculate_percentage)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 4
#       1 base_joined = gpd.sjoin(sj_zips, base_zones, how='inner', predicate='intersects')
#       3 base_percentages = (
# ----> 4     base_joined.groupby('ZIPCODE').apply(calculate_percentage)
#       5     .reset_index(name='multifam_percentage_2012')
#       6 )
#       8 base_joined = base_joined.merge(base_percentages, on = 'ZIPCODE', how = 'left')
#      10 abbrev_base = base_joined[['ZIPCODE', 'FACILITYID', 'ZONINGABBREV', 'multifam_percentage_2012']]
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# TypeError: DataFrame.reset_index() got an unexpected keyword argument 'name'

# %%
zones_15 = gpd.read_file('zoning_data/Zoning_2015.geojson')

# %%
#is this the right crs?
zones_15 = zones_15.to_crs(sj_zones.crs)

joined_15 = gpd.sjoin(sj_zips, zones_15, how='inner', predicate='intersects')

percentages_2015 = (
    joined_15.groupby('ZIPCODE').apply(calculate_percentage)
    .reset_index(name='multifam_percentage_2015')
)

joined_15 = joined_15.merge(percentages_2015, on = 'ZIPCODE', how = 'left')

abbrev_15 = joined_15[['ZIPCODE', 'FACILITYID', 'ZONINGABBREV', 'multifam_percentage_2015']] 
abbrev_15['ZIPCODE'] = abbrev_15['ZIPCODE'].astype('int64')
#i think it should be objectid
# Out:
# /var/folders/dl/8n__h2151hd3n3gtfckwb75w0000gn/T/ipykernel_93981/909249531.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   abbrev_15['ZIPCODE'] = abbrev_15['ZIPCODE'].astype('int64')

# %%
to_join_base = abbrev_base[['ZIPCODE', 'multifam_percentage_2012']].groupby('ZIPCODE').max()
to_join_15 = abbrev_15[['ZIPCODE', 'multifam_percentage_2015']].groupby('ZIPCODE').max()
to_join_final = abbrev_data[['ZIPCODE', 'multifam_percentage']].groupby('ZIPCODE').max()

# %%
temp = to_join_base.merge(to_join_15, how = 'inner', left_index = True, right_index = True)

# %%
zip_panel = temp.merge(to_join_final, how = 'inner', left_index = True, right_index = True)

# %%
zip_panel['intial_diff'] = zip_panel['multifam_percentage_2015'] - zip_panel['multifam_percentage_2012']
zip_panel['final_diff'] = zip_panel['multifam_percentage'] - zip_panel['multifam_percentage_2015']
zip_panel
# Out:
#          multifam_percentage_2012  multifam_percentage_2015  \
# ZIPCODE
# 94089                    0.000000                  0.000000
# 95002                    9.302326                  9.302326
# 95008                   30.666667                 32.432432
# 95013                    0.000000                  0.000000
# 95014                   28.571429                 30.769231
# 95032                   26.666667                 26.666667
# 95035                   12.000000                 12.000000
# 95037                    2.127660                  2.127660
# 95050                   12.500000                 12.500000
# 95054                    0.000000                  0.000000
# 95070                   28.571429                 28.571429
# 95110                   18.636364                 18.141593
# 95111                   23.222749                 22.685185
# 95112                   16.331658                 16.136919
# 95113                   13.333333                 11.764706
# 95116                   28.286853                 29.237288
# 95117                   29.801325                 31.372549
# 95118                   26.900585                 26.900585
# 95119                    6.122449                  6.122449
# 95120                    5.172414                  5.056180
# 95121                    6.369427                  6.211180
# 95122                   22.580645                 22.459893
# 95123                   15.151515                 15.086207
# 95124                   37.696335                 37.305699
# 95125                   23.809524                 23.384615
# 95126                   26.100629                 26.363636
# 95127                   19.724771                 19.178082
# 95128                   34.972678                 34.759358
# 95129                   34.351145                 34.883721
# 95130                   38.095238                 38.095238
# 95131                    0.921659                  0.909091
# 95132                   15.625000                 15.503876
# 95133                   14.788732                 14.685315
# 95134                    6.741573                  6.521739
# 95135                    1.503759                  1.481481
# 95136                   10.112360                  9.782609
# 95138                    1.369863                  1.307190
# 95139                    0.000000                  0.000000
# 95140                    0.000000                  0.000000
# 95141                    0.000000                  0.000000
# 95148                    9.243697                  9.243697
# 95192                   20.000000                 28.571429
#
#          multifam_percentage  intial_diff  final_diff
# ZIPCODE
# 94089               0.000000     0.000000    0.000000
# 95002              14.285714     0.000000    4.983389
# 95008              27.659574     1.765766   -4.772858
# 95013               0.000000     0.000000    0.000000
# 95014              33.333333     2.197802    2.564103
# 95032               6.976744     0.000000  -19.689922
# 95035               0.000000     0.000000  -12.000000
# 95037               0.000000     0.000000   -2.127660
# 95050              19.230769     0.000000    6.730769
# 95054               0.000000     0.000000    0.000000
# 95070              20.588235     0.000000   -7.983193
# 95110              26.470588    -0.494771    8.328995
# 95111              15.139442    -0.537564   -7.545743
# 95112              37.258348    -0.194739   21.121429
# 95113               7.377049    -1.568627   -4.387657
# 95116              34.436090     0.950436    5.198802
# 95117              35.013263     1.571225    3.640714
# 95118              16.631130     0.000000  -10.269455
# 95119               3.305785     0.000000   -2.816664
# 95120               2.127660    -0.116234   -2.928520
# 95121               5.084746    -0.158247   -1.126434
# 95122              17.068273    -0.120752   -5.391620
# 95123              10.945274    -0.065308   -4.140933
# 95124              17.605634    -0.390636  -19.700066
# 95125              21.844660    -0.424908   -1.539955
# 95126              33.842239     0.263007    7.478603
# 95127              13.678373    -0.546688   -5.499709
# 95128              32.783883    -0.213319   -1.975476
# 95129              20.776699     0.532576  -14.107022
# 95130              20.000000     0.000000  -18.095238
# 95131               0.652174    -0.012568   -0.256917
# 95132               7.901235    -0.121124   -7.602641
# 95133              12.500000    -0.103418   -2.185315
# 95134               3.658537    -0.219834   -2.863203
# 95135               1.400560    -0.022278   -0.080921
# 95136               5.465587    -0.329751   -4.317022
# 95138               1.173021    -0.062673   -0.134169
# 95139               0.000000     0.000000    0.000000
# 95140               0.000000     0.000000    0.000000
# 95141               0.000000     0.000000    0.000000
# 95148               2.736842     0.000000   -6.506855
# 95192               0.000000     8.571429  -28.571429

# %%
#abbrev_data['ZONINGABBREV'].value_counts()

# %% [markdown]
# # Rent data

# %%
rents = pd.read_excel('fy2023_safmrs_revised.xlsx')

# %%
rents.rename({
    'ZIP\nCode': 'ZIP Code', 
    'SAFMR\n0BR': 'SAFMR 0BR',
    'SAFMR\n0BR - 90%\nPayment\nStandard': 'SAFMR 0BR - 90% Payment Standard',
    'SAFMR\n0BR - 110%\nPayment\nStandard': 'SAFMR 0BR - 110% Payment Standard',
    'SAFMR\n1BR': 'SAFMR 1BR',
       'SAFMR\n1BR - 90%\nPayment\nStandard': 'SAFMR 1BR - 90% Payment Standard',
       'SAFMR\n1BR - 110%\nPayment\nStandard': 'SAFMR 1BR - 110% Payment Standard', 
    'SAFMR\n2BR': 'SAFMR 2BR',
       'SAFMR\n2BR - 90%\nPayment\nStandard': 'SAFMR 2BR - 90% Payment Standard',
       'SAFMR\n2BR - 110%\nPayment\nStandard': 'SAFMR 2BR - 110% Payment Standard', 
    'SAFMR\n3BR': 'SAFMR 3BR',
       'SAFMR\n3BR - 90%\nPayment\nStandard': 'SAFMR 3BR - 90% Payment Standard',
       'SAFMR\n3BR - 110%\nPayment\nStandard': 'SAFMR 3BR - 110% Payment Standard', 
    'SAFMR\n4BR': 'SAFMR 4BR',
       'SAFMR\n4BR - 90%\nPayment\nStandard': 'SAFMR 4BR - 90% Payment Standard',
       'SAFMR\n4BR - 110%\nPayment\nStandard': 'SAFMR 4BR - 110% Payment Standard'
}, axis = 1, inplace = True)

# %%
#rents.head()

# %%
abbrev_rents = rents[['ZIP Code', 'SAFMR 0BR', 'SAFMR 1BR',
                     'SAFMR 2BR', 'SAFMR 3BR', 'SAFMR 4BR']]
del rents

# %%
abbrev_rents.head()
# Out:
#    ZIP Code  SAFMR 0BR  SAFMR 1BR  SAFMR 2BR  SAFMR 3BR  SAFMR 4BR
# 0     76437        620        660        860       1160       1440
# 1     76443        620        660        860       1160       1440
# 2     76464        620        660        860       1160       1440
# 3     76469        620        660        860       1160       1440
# 4     79501        660        700        900       1220       1480

# %%
rents_2012 = pd.read_excel('small_area_fmrs_fy2012.xls')

# %%
rents_2012 = rents_2012[rents_2012['County Name'] == 'Santa Clara County']

# %%
rents_2012 = rents_2012[['ZIP', 'area_rent_br0', 'area_rent_br1', 'area_rent_br2', 'area_rent_br3', 'area_rent_br4']]

# %%
rents_2012.rename({
    'area_rent_br0': '0BR_base', 'area_rent_br1': '1BR_base', 
    'area_rent_br2': '2BR_base', 'area_rent_br3': '3BR_base', 
    'area_rent_br4': '4BR_base'
}, axis = 1, inplace = True)

# %%
rents_2012['ZIP'] = rents_2012['ZIP'].astype('int64')

# %%
merged_rents = rents_2012.merge(abbrev_rents, left_on = 'ZIP', right_on = 'ZIP Code')

# %%
merged_rents
# Out:
#       ZIP  0BR_base  1BR_base  2BR_base  3BR_base  4BR_base  ZIP Code  \
# 0   94020      1080      1470      1630      2310      2860     94020
# 1   94020      1080      1470      1630      2310      2860     94020
# 2   94022      1080      1470      1630      2310      2860     94022
# 3   94024      1520      2060      2290      3240      4020     94024
# 4   94028      1080      1470      1630      2310      2860     94028
# ..    ...       ...       ...       ...       ...       ...       ...
# 71  95138      1480      2000      2230      3160      3910     95138
# 72  95139      1260      1710      1900      2690      3330     95139
# 73  95140      1080      1470      1630      2310      2860     95140
# 74  95141      1080      1470      1630      2310      2860     95141
# 75  95148      1460      1980      2200      3120      3860     95148
#
#     SAFMR 0BR  SAFMR 1BR  SAFMR 2BR  SAFMR 3BR  SAFMR 4BR
# 0        1980       2380       2910       3710       4040
# 1        1980       2380       2910       3710       4040
# 2        3160       3570       4180       5330       5970
# 3        3110       3510       4110       5240       5870
# 4        2390       2850       3380       4210       4660
# ..        ...        ...        ...        ...        ...
# 71       2530       2860       3350       4270       4790
# 72       2670       3020       3530       4500       5040
# 73       2110       2440       2910       3750       4300
# 74       2220       2510       2940       3750       4200
# 75       2740       3100       3630       4630       5190
#
# [76 rows x 12 columns]

# %%
merged_rents['0BR_change'] = merged_rents['SAFMR 0BR'] - merged_rents['0BR_base']
merged_rents['1BR_change'] = merged_rents['SAFMR 1BR'] - merged_rents['1BR_base']
merged_rents['2BR_change'] = merged_rents['SAFMR 2BR'] - merged_rents['2BR_base']
merged_rents['3BR_change'] = merged_rents['SAFMR 3BR'] - merged_rents['4BR_base']
merged_rents['4BR_change'] = merged_rents['SAFMR 4BR'] - merged_rents['4BR_base']

changes = merged_rents[['ZIP', '0BR_change', '1BR_change', 
                        '2BR_change', '3BR_change', '4BR_change']]

# %%
changes['ZIP'].unique()
# Out:
# array([94020, 94022, 94024, 94028, 94040, 94041, 94043, 94085, 94086,
#        94087, 94089, 94301, 94303, 94304, 94305, 94306, 94539, 94550,
#        95002, 95008, 95013, 95014, 95020, 95023, 95030, 95032, 95033,
#        95035, 95037, 95046, 95050, 95051, 95053, 95054, 95070, 95076,
#        95110, 95111, 95112, 95113, 95116, 95117, 95118, 95119, 95120,
#        95121, 95122, 95123, 95124, 95125, 95126, 95127, 95128, 95129,
#        95130, 95131, 95132, 95133, 95134, 95135, 95136, 95138, 95139,
#        95140, 95141, 95148])

# %%
len(abbrev_data['ZIPCODE'].unique())
# Out:
# 42

# %%
full = abbrev_data.merge(changes, left_on = 'ZIPCODE', right_on = 'ZIP', how = 'inner')
full.drop('ZIP', axis=1, inplace=True)

# %%
full
# Out:
#        ZIPCODE FACILITYID ZONINGABBREV  multifam_percentage  0BR_change  \
# 0        95113      11843          R-M             4.098361        1950
# 1        95113      11854          R-M             4.098361        1950
# 2        95113       7463          MUC             4.098361        1950
# 3        95113       7473           CP             4.098361        1950
# 4        95113       7476           CP             4.098361        1950
# ...        ...        ...          ...                  ...         ...
# 13976    95119       7769           IP             1.652893        1050
# 13977    95119       7771           IP             1.652893        1050
# 13978    95119      12099        A(PD)             1.652893        1050
# 13979    95119       6464        A(PD)             1.652893        1050
# 13980    95119       6465       IP(PD)             1.652893        1050
#
#        1BR_change  2BR_change  3BR_change  4BR_change
# 0            2050        2450        2580        3130
# 1            2050        2450        2580        3130
# 2            2050        2450        2580        3130
# 3            2050        2450        2580        3130
# 4            2050        2450        2580        3130
# ...           ...         ...         ...         ...
# 13976         890        1150         510         990
# 13977         890        1150         510         990
# 13978         890        1150         510         990
# 13979         890        1150         510         990
# 13980         890        1150         510         990
#
# [13981 rows x 9 columns]

# %%
full['multifam_percentage']
# Out:
# 0        4.098361
# 1        4.098361
# 2        4.098361
# 3        4.098361
# 4        4.098361
#            ...
# 13976    1.652893
# 13977    1.652893
# 13978    1.652893
# 13979    1.652893
# 13980    1.652893
# Name: multifam_percentage, Length: 13981, dtype: float64

# %%
sorted(full['ZIPCODE'].unique())
# Out:
# [94089,
#  95002,
#  95008,
#  95013,
#  95014,
#  95032,
#  95035,
#  95037,
#  95050,
#  95054,
#  95070,
#  95110,
#  95111,
#  95112,
#  95113,
#  95116,
#  95117,
#  95118,
#  95119,
#  95120,
#  95121,
#  95122,
#  95123,
#  95124,
#  95125,
#  95126,
#  95127,
#  95128,
#  95129,
#  95130,
#  95131,
#  95132,
#  95133,
#  95134,
#  95135,
#  95136,
#  95138,
#  95139,
#  95140,
#  95141,
#  95148]

# %%
#2011 rents

# %%
#issue!
print('Problem: zip code rent data before 2018 were estimates')
print(len(rents_2011[rents_2011['County_Name'] == 'Santa Clara County']['area_rent_br1'].unique()))

(len(rents_2011[rents_2011['County_Name'] == 'Santa Clara County']['zip'].unique()))
# Out:
# Problem: zip code rent data before 2018 were estimates
# 29
# 63

# %% [markdown]
# # Demographic info (controls)

# %%
test_demo = pd.read_csv('controls_data/full_2012_demographics.csv')

# %%
test_demo['Label (Grouping)'] = test_demo['Label (Grouping)'].apply(lambda x: str(x).replace(u'\xa0', u''))
test_demo.columns = test_demo.columns.str.replace('!!', ' ')

# %%
test_demo['Label (Grouping)'] = test_demo['Label (Grouping)'].apply(lambda x: str(x).replace(u'\xa0', u''))
test_demo.columns = test_demo.columns.str.replace('!!', ' ')


og = test_demo.copy()

#to get the rows outside of "one race" dropdown
rows = [2] + list(range(60, 70))
test_demo = test_demo.iloc[rows]


#note that median age and total housing units are in 'estimate' columns
vals_to_keep = {'Male', 'White', 'Black or African American',
       'American Indian and Alaska Native', 'Asian', 'Native Hawaiian and Other Pacific Islander',
                'Some Other Race', 'Hispanic or Latino (of any race)',
               }

test_demo = test_demo[test_demo['Label (Grouping)'].isin(vals_to_keep)]


test_demo = test_demo.filter(regex='^(?=.*(?i)percent|label)(?!.*(?i)percent margin of error)')

pivoted = test_demo.set_index('Label (Grouping)').T
pivoted.reset_index(inplace = True)
pivoted.rename({'index': 'ZIP'}, axis = 1, inplace = True)
pivoted['ZIP'] = pivoted['ZIP'].str.extract(r'ZCTA5 (\d+) Percent')[0]

# %%
og = og.filter(regex='^(?=.*(?i)estimate|label)(?!.*(?i)estimate margin of error)')

og = og.set_index('Label (Grouping)')
og_pivot = og[(og.index == 'Total housing units') | (og.index == 'Median age (years)') | 
              (og.index == 'Total population')].T

og_pivot = og_pivot.T.drop_duplicates(keep = 'first').T

og_pivot.reset_index(inplace = True)
og_pivot.rename({'index': 'ZIP'}, axis = 1, inplace = True)
og_pivot['ZIP'] = og_pivot['ZIP'].str.extract(r'ZCTA5 (\d+) Estimate')[0]

full_controls = pivoted.merge(og_pivot, on = 'ZIP')

# %%
def clean_totals(val):
    if isinstance(val, str):
        return float(val.replace(',', ''))
    else:
        return val

# %%
#cleaning

full_controls.replace('-', '0', inplace = True)

def clean_pct(column):
    return column.str.rstrip('%').astype(float) / 100


to_clean = ['Male', 'White', 'Black or African American', 'American Indian and Alaska Native',
           'Asian', 'Native Hawaiian and Other Pacific Islander', 'Hispanic or Latino (of any race)']


full_controls[to_clean] = full_controls[to_clean].apply(clean_pct)

full_controls['Total population'] = full_controls['Total population'].apply(clean_totals)

full_controls['Total housing units'] = full_controls['Total housing units'].apply(clean_totals)



full_controls['Density per unit'] = full_controls['Total population'] / full_controls['Total housing units']
full_controls
# Out:
# Label (Grouping)    ZIP   Male  White  Black or African American  \
# 0                 94089  0.485  0.477                      0.026
# 1                 95002  0.491  0.547                      0.013
# 2                 95008  0.493  0.750                      0.029
# 3                 95013  0.000  0.000                      0.000
# 4                 95014  0.490  0.349                      0.006
# 5                 95032  0.480  0.851                      0.013
# 6                 95035  0.511  0.243                      0.036
# 7                 95037  0.484  0.739                      0.034
# 8                 95050  0.507  0.623                      0.043
# 9                 95054  0.515  0.295                      0.056
# 10                95070  0.494  0.543                      0.003
# 11                95110  0.528  0.544                      0.033
# 12                95111  0.505  0.474                      0.037
# 13                95112  0.526  0.496                      0.051
# 14                95113  0.528  0.433                      0.117
# 15                95116  0.512  0.453                      0.032
# 16                95117  0.534  0.583                      0.059
# 17                95118  0.494  0.711                      0.037
# 18                95119  0.518  0.655                      0.064
# 19                95120  0.496  0.671                      0.016
# 20                95121  0.495  0.380                      0.030
# 21                95122  0.500  0.434                      0.020
# 22                95123  0.488  0.700                      0.043
# 23                95124  0.505  0.770                      0.033
# 24                95125  0.470  0.715                      0.040
# 25                95126  0.509  0.573                      0.055
# 26                95127  0.521  0.529                      0.036
# 27                95128  0.522  0.599                      0.052
# 28                95129  0.496  0.350                      0.027
# 29                95130  0.517  0.584                      0.028
# 30                95131  0.509  0.192                      0.044
# 31                95132  0.499  0.259                      0.033
# 32                95133  0.489  0.292                      0.039
# 33                95134  0.540  0.338                      0.097
# 34                95135  0.476  0.424                      0.019
# 35                95136  0.493  0.555                      0.049
# 36                95138  0.469  0.451                      0.038
# 37                95139  0.484  0.726                      0.026
# 38                95140  0.579  1.000                      0.000
# 39                95148  0.494  0.281                      0.045
#
# Label (Grouping)  American Indian and Alaska Native  Asian  \
# 0                                             0.014  0.441
# 1                                             0.010  0.120
# 2                                             0.015  0.201
# 3                                             0.000  0.000
# 4                                             0.006  0.643
# 5                                             0.016  0.149
# 6                                             0.011  0.653
# 7                                             0.014  0.127
# 8                                             0.013  0.219
# 9                                             0.002  0.638
# 10                                            0.002  0.479
# 11                                            0.016  0.112
# 12                                            0.019  0.348
# 13                                            0.027  0.258
# 14                                            0.020  0.406
# 15                                            0.013  0.245
# 16                                            0.005  0.244
# 17                                            0.019  0.191
# 18                                            0.018  0.223
# 19                                            0.008  0.331
# 20                                            0.017  0.554
# 21                                            0.018  0.328
# 22                                            0.017  0.203
# 23                                            0.016  0.178
# 24                                            0.015  0.142
# 25                                            0.012  0.197
# 26                                            0.016  0.237
# 27                                            0.017  0.178
# 28                                            0.010  0.623
# 29                                            0.019  0.300
# 30                                            0.010  0.709
# 31                                            0.003  0.635
# 32                                            0.015  0.602
# 33                                            0.014  0.506
# 34                                            0.010  0.544
# 35                                            0.018  0.320
# 36                                            0.002  0.476
# 37                                            0.017  0.171
# 38                                            0.000  0.000
# 39                                            0.011  0.594
#
# Label (Grouping)  Native Hawaiian and Other Pacific Islander  \
# 0                                                      0.001
# 1                                                      0.000
# 2                                                      0.008
# 3                                                      0.000
# 4                                                      0.004
# 5                                                      0.002
# 6                                                      0.012
# 7                                                      0.010
# 8                                                      0.009
# 9                                                      0.005
# 10                                                     0.001
# 11                                                     0.007
# 12                                                     0.007
# 13                                                     0.006
# 14                                                     0.000
# 15                                                     0.007
# 16                                                     0.002
# 17                                                     0.006
# 18                                                     0.017
# 19                                                     0.003
# 20                                                     0.013
# 21                                                     0.008
# 22                                                     0.008
# 23                                                     0.004
# 24                                                     0.008
# 25                                                     0.009
# 26                                                     0.007
# 27                                                     0.012
# 28                                                     0.004
# 29                                                     0.004
# 30                                                     0.015
# 31                                                     0.011
# 32                                                     0.013
# 33                                                     0.007
# 34                                                     0.009
# 35                                                     0.016
# 36                                                     0.005
# 37                                                     0.006
# 38                                                     0.000
# 39                                                     0.012
#
# Label (Grouping)  Hispanic or Latino (of any race)  Total population  \
# 0                                            0.209           20282.0
# 1                                            0.709            1906.0
# 2                                            0.164           44909.0
# 3                                            0.000               0.0
# 4                                            0.051           60690.0
# 5                                            0.066           25039.0
# 6                                            0.156           67380.0
# 7                                            0.357           45924.0
# 8                                            0.325           36587.0
# 9                                            0.113           23188.0
# 10                                           0.030           30533.0
# 11                                           0.645           18179.0
# 12                                           0.527           57125.0
# 13                                           0.440           53268.0
# 14                                           0.094             702.0
# 15                                           0.646           49728.0
# 16                                           0.361           30980.0
# 17                                           0.258           31312.0
# 18                                           0.312            9466.0
# 19                                           0.083           38351.0
# 20                                           0.317           37135.0
# 21                                           0.607           54873.0
# 22                                           0.319           63495.0
# 23                                           0.151           47854.0
# 24                                           0.259           52805.0
# 25                                           0.383           31965.0
# 26                                           0.580           64392.0
# 27                                           0.379           36020.0
# 28                                           0.064           39436.0
# 29                                           0.208           14529.0
# 30                                           0.117           28990.0
# 31                                           0.166           40882.0
# 32                                           0.250           26189.0
# 33                                           0.153           15316.0
# 34                                           0.125           21159.0
# 35                                           0.276           42565.0
# 36                                           0.193           19104.0
# 37                                           0.385            6690.0
# 38                                           0.312             321.0
# 39                                           0.244           45677.0
#
# Label (Grouping) Median age (years)  Total housing units  Density per unit
# 0                              36.2               7676.0          2.642262
# 1                              35.6                577.0          3.303293
# 2                              37.8              19203.0          2.338645
# 3                                 0                  0.0               NaN
# 4                              39.7              22269.0          2.725313
# 5                              43.3              10433.0          2.399981
# 6                              36.7              20253.0          3.326915
# 7                              37.7              15598.0          2.944224
# 8                              34.0              14487.0          2.525506
# 9                              33.4               8637.0          2.684728
# 10                             47.5              11452.0          2.666172
# 11                             30.6               6227.0          2.919383
# 12                             31.5              15877.0          3.597972
# 13                             30.8              20179.0          2.639774
# 14                             41.7                605.0          1.160331
# 15                             31.4              13953.0          3.563965
# 16                             32.2              11235.0          2.757454
# 17                             37.7              11654.0          2.686803
# 18                             38.5               3129.0          3.025248
# 19                             43.7              12692.0          3.021667
# 20                             34.7               9685.0          3.834280
# 21                             30.9              13089.0          4.192299
# 22                             35.4              22356.0          2.840177
# 23                             39.6              17189.0          2.783990
# 24                             39.5              21751.0          2.427704
# 25                             33.7              14077.0          2.270725
# 26                             34.4              17188.0          3.746335
# 27                             35.9              14509.0          2.482597
# 28                             38.5              14661.0          2.689857
# 29                             36.3               5316.0          2.733070
# 30                             35.5               9310.0          3.113856
# 31                             38.3              12026.0          3.399468
# 32                             36.5               7717.0          3.393676
# 33                             31.7               7086.0          2.161445
# 34                             42.6               7426.0          2.849313
# 35                             35.6              15389.0          2.765937
# 36                             36.0               6068.0          3.148319
# 37                             36.1               2275.0          2.940659
# 38                             43.8                104.0          3.086538
# 39                             36.4              11859.0          3.851674

# %%
all_zips = set(
[94089,
 95002,
 95008,
 95013,
 95014,
 95032,
 95035,
 95037,
 95050,
 95054,
 95070,
 95110,
 95111,
 95112,
 95113,
 95116,
 95117,
 95118,
 95119,
 95120,
 95121,
 95122,
 95123,
 95124,
 95125,
 95126,
 95127,
 95128,
 95129,
 95130,
 95131,
 95132,
 95133,
 95134,
 95135,
 95136,
 95138,
 95139,
 95140,
 95141,
 95148])

# %%
#in 2021 data
all_zips.difference(set(pivoted['ZIP'].astype(int)))
# Out:
# {95141}

# %%
#concat median age, sex ratio, total housing units (?)

# %%
#keep median age, all ethnic groups, sex ratio

# %% [markdown]
# **Median income**

# %%
raw_med_12 = pd.read_csv('controls_data/sj_med_income_2012.csv')

# %%
raw_med_12.columns = raw_med_12.columns.str.replace('!!', ' ')

# %%
mean_med = raw_med_12[(raw_med_12['Label (Grouping)'] == 'Median income (dollars)') 
           | (raw_med_12['Label (Grouping)'] == 'Mean income (dollars)')]

# %%
mean_med = mean_med.filter(regex=r'^(ZCTA5 \d{5} Households Estimate|Label \(Grouping\))$')

# %%
mean_med
# Out:
#            Label (Grouping) ZCTA5 94089 Households Estimate  \
# 11  Median income (dollars)                          80,625
# 12    Mean income (dollars)                          96,423
#
#    ZCTA5 95002 Households Estimate ZCTA5 95008 Households Estimate  \
# 11                          83,125                          83,306
# 12                          94,243                         105,661
#
#    ZCTA5 95013 Households Estimate ZCTA5 95014 Households Estimate  \
# 11                               -                         125,168
# 12                               -                         147,786
#
#    ZCTA5 95032 Households Estimate ZCTA5 95035 Households Estimate  \
# 11                         122,512                          99,527
# 12                         154,043                         113,492
#
#    ZCTA5 95037 Households Estimate ZCTA5 95050 Households Estimate  ...  \
# 11                          93,604                          65,371  ...
# 12                         122,241                          84,184  ...
#
#    ZCTA5 95131 Households Estimate ZCTA5 95132 Households Estimate  \
# 11                         102,954                          93,896
# 12                         118,843                         105,020
#
#    ZCTA5 95133 Households Estimate ZCTA5 95134 Households Estimate  \
# 11                          67,444                         104,814
# 12                          86,580                         119,323
#
#    ZCTA5 95135 Households Estimate ZCTA5 95136 Households Estimate  \
# 11                         113,806                          87,564
# 12                         134,791                         104,888
#
#    ZCTA5 95138 Households Estimate ZCTA5 95139 Households Estimate  \
# 11                         144,912                          95,000
# 12                         191,938                         113,708
#
#    ZCTA5 95140 Households Estimate ZCTA5 95148 Households Estimate
# 11                         162,167                         105,577
# 12                         148,348                         121,847
#
# [2 rows x 41 columns]

# %%
pivoted_income = mean_med.set_index('Label (Grouping)').T


pivoted_income.reset_index(inplace = True)
pivoted_income.rename({'index': 'ZIP'}, axis = 1, inplace = True)
pivoted_income['ZIP'] = pivoted_income['ZIP'].str.extract(r'ZCTA5 (\d+) Households Estimate')[0]
pivoted_income.replace({'-': np.nan}, inplace = True)

pivoted_income['Median income (dollars)'] = (
    pivoted_income['Median income (dollars)'].str.replace(',', '').astype('float64')
)

pivoted_income['Mean income (dollars)'] = (
    pivoted_income['Mean income (dollars)'].str.replace(',', '').astype('float64')
)

# %%
pivoted_income
# Out:
# Label (Grouping)    ZIP  Median income (dollars)  Mean income (dollars)
# 0                 94089                  80625.0                96423.0
# 1                 95002                  83125.0                94243.0
# 2                 95008                  83306.0               105661.0
# 3                 95013                      NaN                    NaN
# 4                 95014                 125168.0               147786.0
# 5                 95032                 122512.0               154043.0
# 6                 95035                  99527.0               113492.0
# 7                 95037                  93604.0               122241.0
# 8                 95050                  65371.0                84184.0
# 9                 95054                 115068.0               127989.0
# 10                95070                 156762.0               203896.0
# 11                95110                  63125.0                79215.0
# 12                95111                  56400.0                69781.0
# 13                95112                  48070.0                69909.0
# 14                95113                  19737.0                51372.0
# 15                95116                  48838.0                60100.0
# 16                95117                  64285.0                84424.0
# 17                95118                  86471.0               102110.0
# 18                95119                 110974.0               118519.0
# 19                95120                 148801.0               171065.0
# 20                95121                  82568.0               100290.0
# 21                95122                  56581.0                67116.0
# 22                95123                  85494.0               100041.0
# 23                95124                 104514.0               120841.0
# 24                95125                  95316.0               130583.0
# 25                95126                  69407.0                94710.0
# 26                95127                  69365.0                86953.0
# 27                95128                  65805.0                91481.0
# 28                95129                 102701.0               123721.0
# 29                95130                  98819.0               111725.0
# 30                95131                 102954.0               118843.0
# 31                95132                  93896.0               105020.0
# 32                95133                  67444.0                86580.0
# 33                95134                 104814.0               119323.0
# 34                95135                 113806.0               134791.0
# 35                95136                  87564.0               104888.0
# 36                95138                 144912.0               191938.0
# 37                95139                  95000.0               113708.0
# 38                95140                 162167.0               148348.0
# 39                95148                 105577.0               121847.0
